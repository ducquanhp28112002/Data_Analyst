# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Lấy dữ liệu
df = pd.read_csv("daily-min-temperatures.csv")
df.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
# Hiển thị thống kê của dữ liệu nhiệt độ
df["Temp"].describe()
# Out:
# count    3650.000000
# mean       11.177753
# std         4.071837
# min         0.000000
# 25%         8.300000
# 50%        11.000000
# 75%        14.000000
# max        26.300000
# Name: Temp, dtype: float64

# %% [markdown]
# - Vẽ biểu đồ Histogram phân tích các giá trị thống kê như max, min, mode, tần suất.

# %%
# Vẽ biểu đồ 
plt.hist(df["Temp"], bins = 45)
plt.show()

# %%
# Tinh chỉnh biểu đồ
plt.hist(df["Temp"], bins = 45, range = (1, 23), histtype = "step")
plt.title("Temperature Histogram", fontsize = 16)
plt.show()

# %% [markdown]
# ##### Nhận xét:
# - Giá trị xuất hiện nhiều nhất trong khoảng 10-11 độ.
# - Có một số giá trị bất thường ở cả hai phía. Một số rất ít ngày có nhiệt độ cao bất thường trên 23 độ và thấp dưới 1 độ.
# - Nhìn chung, nếu loại bỏ các ngày có giá trị bất thường, có thể nói nhiệt độ tuân theo phân phối chuẩn.

# %% [markdown]
# - Vẽ biểu đồ đường phân tích xu hướng thay đổi nhiệt độ theo thời gian.

# %%
plt.plot(df["Date"], df["Temp"])
plt.title("Daily Temperature", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Temp", fontsize = 16)
plt.show()

# %% [markdown]
# ##### Nhận xét:
# - Có thể thay xu hướng thay đổi nhiệt độ có tính chu kỳ.
# - Dựa vào đồ thị, ta phán đoán chu kỳ thay đổi của nhiệt độ là theo năm.
# - Tuy nhiên, do khoảng thời gian biểu diễn dài nên khó có thể nhìn chi tiết xu hướng biến đổi nhiệt độ trong năm. Do đó ta vẽ bổ sung biểu đồ đường thể hiện xu hướng nhiệt độ theo từng năm quan tâm.

# %%
df["Date"] = pd.to_datetime(df["Date"])
bounds = ["1/1/1990", "12/31/1990"]
bounds = pd.to_datetime(bounds)
df_1 = df[(df["Date"] >= bounds[0]) & (df["Date"] <= bounds[1])]
plt.plot(df_1["Date"], df_1["Temp"])
plt.title("Daily Temperature in 1990", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Temp", fontsize = 14)
plt.show()

# %% [markdown]
# ##### Nhận xét:
# - Nhiệt độ có xu hướng giảm từ tháng 5 và bắt đầu tăng trở lại vào tháng 9.
# - 3 tháng đầu năm có nhiệt độ trung bình cao nhất.
