# %%
import pandas as pd

# %% [markdown]
# - Đọc bộ dữ liệu, cho biết số dòng, số cột và kiểu dữ liệu của các thuộc tính.

# %%
# Đọc dữ liệu
df = pd.read_csv("OnlineRetail.csv", encoding = "ISO-8859-1")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# Số dòng
df.shape[0]
# Out:
# 541909

# %%
# Số cột
df.shape[1]
# Out:
# 8

# %%
# Kiểu dữ liệu của các thuộc tính
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# - Xây dựng bảng Pivot table, với mỗi Số hóa đơn tính trung bình cộng số lượng các mặt hàng theo từng Quốc gia.

# %%
df.pivot_table(values = "Quantity", index = "InvoiceNo", columns = "Country", aggfunc = "mean")
# Out:
# Country    Australia  Austria  Bahrain  Belgium  Brazil  Canada  \
# InvoiceNo
# 536365           NaN      NaN      NaN      NaN     NaN     NaN
# 536366           NaN      NaN      NaN      NaN     NaN     NaN
# 536367           NaN      NaN      NaN      NaN     NaN     NaN
# 536368           NaN      NaN      NaN      NaN     NaN     NaN
# 536369           NaN      NaN      NaN      NaN     NaN     NaN
# ...              ...      ...      ...      ...     ...     ...
# C581484          NaN      NaN      NaN      NaN     NaN     NaN
# C581490          NaN      NaN      NaN      NaN     NaN     NaN
# C581499          NaN      NaN      NaN      NaN     NaN     NaN
# C581568          NaN      NaN      NaN      NaN     NaN     NaN
# C581569          NaN      NaN      NaN      NaN     NaN     NaN
#
# Country    Channel Islands  Cyprus  Czech Republic  Denmark  ...  RSA  \
# InvoiceNo                                                    ...
# ...

# %% [markdown]
# - Xây dựng bảng Pivot table, với mỗi khách hàng cho biết số lượng mua hàng lớn nhất và nhỏ nhất theo kho.

# %%
df.pivot_table(values = "Quantity", index = "StockCode", columns = "CustomerID", aggfunc = {min, max})
# Out:
#                max                                                          \
# CustomerID 12346.0 12347.0 12348.0 12349.0 12350.0 12352.0 12353.0 12354.0
# StockCode
# 10002          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10080          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10120          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10123C         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10124A         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# D              NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# DOT            NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# M              NaN     NaN     NaN     NaN     NaN     1.0     NaN     NaN
# PADS           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %% [markdown]
# - Xây dựng bảng Pivot table, với mỗi Mã kho tính tổng số lượng các mặt hàng và trung bình cộng giá.

# %%
import numpy as np

# %%
df.pivot_table(values = ["Quantity", "UnitPrice"], index = "InvoiceNo", columns = "StockCode", aggfunc = {"Quantity": np.sum, "UnitPrice": np.mean})
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22464/1553261687.py in <module>
# ----> 1 df.pivot_table(values = ["Quantity", "UnitPrice"], index = "InvoiceNo", columns = "StockCode", aggfunc = {"Quantity": np.sum, "UnitPrice": np.mean})
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    7949         from pandas.core.reshape.pivot import pivot_table
#    7950
# -> 7951         return pivot_table(
#    7952             self,
#    7953             values=values,
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
# ...

# %% [markdown]
# - Xây dựng bảng Pivot table cho biết tổng số lượng hàng bán được mỗi ngày

# %%
df.pivot_table(values = "Quantity", index = "InvoiceDate", aggfunc = {"Quantity": np.sum})
# Out:
#                  Quantity
# InvoiceDate
# 1/10/2011 10:04       -29
# 1/10/2011 10:07        -4
# 1/10/2011 10:08       -14
# 1/10/2011 10:32       260
# 1/10/2011 10:35       408
# ...                   ...
# 9/9/2011 8:48         104
# 9/9/2011 9:03         105
# 9/9/2011 9:13         372
# 9/9/2011 9:38         203
# 9/9/2011 9:52         782
#
# [23260 rows x 1 columns]
